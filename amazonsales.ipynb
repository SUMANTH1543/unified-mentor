# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
data=pd.read_csv("Amazon Sales data.csv")

# %%
data
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
data.columns
# Out:
# Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Region             object
# Country            object
# Item Type          object
# Sales Channel      object
# Order Priority     object
# Order Date         object
# Order ID            int64
# Ship Date          object
# Units Sold          int64
# Unit Price        float64
# Unit Cost         float64
# Total Revenue     float64
# Total Cost        float64
# Total Profit      float64
# dtype: object

# %%
data.isna().sum()
# Out:
# Region            0
# Country           0
# Item Type         0
# Sales Channel     0
# Order Priority    0
# Order Date        0
# Order ID          0
# Ship Date         0
# Units Sold        0
# Unit Price        0
# Unit Cost         0
# Total Revenue     0
# Total Cost        0
# Total Profit      0
# dtype: int64

# %%
data.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Length: 100, dtype: bool

# %%
columns_to_convert=["Unit Price","Unit Cost","Total Revenue","Total Cost","Total Profit"]
data[columns_to_convert]=data[columns_to_convert].astype(int)
print(data)
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
data.head(10)
# Out:
#                               Region                Country        Item Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
# 5              Australia and Oceania        Solomon Islands        Baby Food
# 6                 Sub-Saharan Africa                 Angola        Household
# 7                 Sub-Saharan Africa           Burkina Faso       Vegetables
# 8                 Sub-Saharan Africa  Republic of the Congo    Personal Care
# 9                 Sub-Saharan Africa                Senegal           Cereal
#
#   Sales Channel Order Priority Order Date   Order ID  Ship Date  Units Sold  \
# ...

# %%
data['Order Date']=pd.to_datetime(data['Order Date'])

# %%
data['month'] = data['Order Date'].dt.month
data['year'] = data['Order Date'].dt.year

# %%
data.head(10)
# Out:
#                               Region                Country        Item Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
# 5              Australia and Oceania        Solomon Islands        Baby Food
# 6                 Sub-Saharan Africa                 Angola        Household
# 7                 Sub-Saharan Africa           Burkina Faso       Vegetables
# 8                 Sub-Saharan Africa  Republic of the Congo    Personal Care
# 9                 Sub-Saharan Africa                Senegal           Cereal
#
#   Sales Channel Order Priority Order Date   Order ID  Ship Date  Units Sold  \
# ...

# %%
data['sales'] = data['Unit Price'] * data['Units Sold']
data.head(10)
# Out:
#                               Region                Country        Item Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
# 5              Australia and Oceania        Solomon Islands        Baby Food
# 6                 Sub-Saharan Africa                 Angola        Household
# 7                 Sub-Saharan Africa           Burkina Faso       Vegetables
# 8                 Sub-Saharan Africa  Republic of the Congo    Personal Care
# 9                 Sub-Saharan Africa                Senegal           Cereal
#
#   Sales Channel Order Priority Order Date   Order ID  Ship Date  Units Sold  \
# ...

# %%
# Month-wise sales trend
month_wise_sales = data.groupby('month')['sales'].sum().reset_index()
print(month_wise_sales)
# Out:
#     month     sales
# 0       1  10466999
# 1       2  24713519
# 2       3   2268718
# 3       4  16172397
# 4       5  13188143
# 5       6   5218803
# 6       7  15636231
# 7       8   1121643
# 8       9   5307357
# 9      10  15270750
# 10     11  20555213
# 11     12   7244705

# %%
# Year-wise sales trend
year_wise_sales = data.groupby('year')['sales'].sum().reset_index()
print(year_wise_sales)
# Out:
#    year     sales
# 0  2010  19170201
# 1  2011  11109758
# 2  2012  31863765
# 3  2013  20311295
# 4  2014  16595394
# 5  2015  12408360
# 6  2016  12358816
# 7  2017  13346889

# %%
# Yearly month-wise sales trend
year_month_wise_sales = data.groupby(['year', 'month'])['sales'].sum().reset_index()
print(year_month_wise_sales)
# Out:
#     year  month    sales
# 0   2010      2  3408579
# 1   2010      5  2583273
# 2   2010      6  1079645
# 3   2010     10  6061481
# 4   2010     11  3456670
# 5   2010     12  2580553
# 6   2011      1  1035883
# 7   2011      2   383332
# 8   2011      4  2796916
# 9   2011      5   269827
# 10  2011      6    19096
# 11  2011      7    96792
# 12  2011      9   574728
# 13  2011     11  5933184
# 14  2012      1  1012542
# 15  2012      2  6700875
# 16  2012      3   994378
# 17  2012      4  4553963
# 18  2012      5  3779730
# 19  2012      6  2129194
# 20  2012      7  4433032
# 21  2012      8   574820
# 22  2012      9  4644213
# 23  2012     10  3041018
# 24  2013      2  3295362
# 25  2013      3   832915
# 26  2013      4  3261510
# 27  2013      6  1351060
# 28  2013      7  8541602
# 29  2013      8    86454
# 30  2013      9    68733
# 31  2013     10  2701534
# 32  2013     12   172125
# 33  2014      2  1814526
# 34  2014      4  4504520
# 35  2014      5  3057879
# ...

# %%
# Plot month-wise sales trend
plt.figure(figsize=(10, 6))
sns.barplot(x='month', y='sales', data=month_wise_sales)
plt.title('Month-wise Sales Trend')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.show()

# %%
# Plot year-wise sales trend
plt.figure(figsize=(10, 5))
sns.lineplot(x='year', y='sales', data=year_wise_sales, marker='o')
plt.title('Year-wise Sales Trend')
plt.xlabel('Year')
plt.ylabel('Sales')
plt.show()
# Out:
# C:\Users\godar\Downloads\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\godar\Downloads\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Plot yearly month-wise sales trend
plt.figure(figsize=(14, 8))
sns.lineplot(x='month', y='sales', hue='year', data=year_month_wise_sales, marker='o')
plt.title('Yearly Month-wise Sales Trend')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.legend(title='Year')
plt.show()
# Out:
# C:\Users\godar\Downloads\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\godar\Downloads\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
data.to_csv(r"C:\Users\godar\OneDrive\Desktop\unified mentor\amazonsales1.csv",index=False)
